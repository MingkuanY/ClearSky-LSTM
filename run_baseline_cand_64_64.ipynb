# %%
import sys
print(sys.executable)
# Out:
# /home/hice1/mchoi345/.conda/envs/dl2/bin/python

# %%
# teacher forcing does not work for this
# !{sys.executable} clearsky_lstm.py \
  --model base_network_cand \
  --stations KAMX \
  --t-in 5 \
  --t-out 5 \
  --batch-size 8 \
  --epochs 20 \
  --lr 0.001 \
  --hidden-ch 64 64 \
  --num-layers 2 \
  --teacher-forcing 0.5 \
  --seed 13
# Out:
# ## You are using the Python ARM Radar Toolkit (Py-ART), an open source
# ## library for working with weather radar data. Py-ART is partly
# ## supported by the U.S. Department of Energy as part of the Atmospheric
# ## Radiation Measurement (ARM) Climate Research Facility, an Office of
# ## Science user facility.
# ##
# ## If you use this software to prepare a publication, please cite:
# ##
# ##     JJ Helmus and SM Collis, JORS 2016, doi: 10.5334/jors.119
#
# Starting model...
# Arguments parsed! sample_dir=samples/20260320/base_network_cand/420j6ajc results_dir=results/20260320/base_network_cand/420j6ajc
# Building dataset...
# Train/val/test split complete!
# Model built!
# Beginning training...
# Note: higher blur score = sharper image!
# Input Range: 0.0000 to 0.8873
# Pred Range: 0.5072 to 0.5265
# Target Range: 0.0000 to 0.8922
# Epoch 1/20 | train: 0.088 | val: 0.081 | blur: 223.669 | MAE: 14.008 | RMSE: 18.995 | RAPSD-dist: 0.803
# Input Range: 0.0000 to 0.9412
# Pred Range: 0.0000 to 0.6346
# Target Range: 0.0000 to 0.9118
# Epoch 2/20 | train: 0.081 | val: 0.080 | blur: 232.090 | MAE: 12.814 | RMSE: 17.869 | RAPSD-dist: 0.762
# Input Range: 0.0000 to 0.8725
# Pred Range: 0.0000 to 0.6882
# Target Range: 0.0000 to 0.9020
# Epoch 3/20 | train: 0.080 | val: 0.079 | blur: 260.228 | MAE: 13.186 | RMSE: 18.303 | RAPSD-dist: 0.784
# Input Range: 0.0000 to 0.8676
# Pred Range: 0.0000 to 0.7134
# Target Range: 0.0000 to 0.8824
# Epoch 4/20 | train: 0.079 | val: 0.078 | blur: 333.440 | MAE: 13.527 | RMSE: 18.554 | RAPSD-dist: 0.796
# Input Range: 0.0000 to 0.8873
# Pred Range: 0.0000 to 0.7090
# Target Range: 0.0000 to 0.8725
# Epoch 5/20 | train: 0.078 | val: 0.078 | blur: 450.119 | MAE: 13.666 | RMSE: 18.696 | RAPSD-dist: 0.801
# Input Range: 0.0000 to 0.9069
# Pred Range: 0.0000 to 0.7626
# Target Range: 0.0000 to 0.8971
# Epoch 6/20 | train: 0.078 | val: 0.078 | blur: 687.672 | MAE: 12.659 | RMSE: 17.948 | RAPSD-dist: 0.776
# Input Range: 0.0000 to 0.9118
# Pred Range: 0.0000 to 0.7750
# Target Range: 0.0000 to 0.9216
# Epoch 7/20 | train: 0.078 | val: 0.077 | blur: 739.430 | MAE: 13.298 | RMSE: 18.575 | RAPSD-dist: 0.806
# Input Range: 0.0000 to 0.8725
# Pred Range: 0.0000 to 0.7294
# Target Range: 0.0000 to 0.8725
# Epoch 8/20 | train: 0.078 | val: 0.077 | blur: 836.004 | MAE: 12.954 | RMSE: 18.189 | RAPSD-dist: 0.791
# Input Range: 0.0000 to 0.8824
# Pred Range: 0.0000 to 0.7414
# Target Range: 0.0000 to 0.8971
# Epoch 9/20 | train: 0.077 | val: 0.077 | blur: 797.381 | MAE: 13.840 | RMSE: 19.097 | RAPSD-dist: 0.827
# Input Range: 0.0000 to 0.8873
# Pred Range: 0.0000 to 0.7450
# Target Range: 0.0000 to 0.8971
# Epoch 10/20 | train: 0.077 | val: 0.077 | blur: 782.385 | MAE: 13.782 | RMSE: 18.996 | RAPSD-dist: 0.819
# Input Range: 0.0000 to 0.8922
# Pred Range: 0.0000 to 0.7560
# Target Range: 0.0000 to 0.8824
# Epoch 11/20 | train: 0.077 | val: 0.077 | blur: 917.009 | MAE: 13.639 | RMSE: 18.871 | RAPSD-dist: 0.823
# Input Range: 0.0000 to 0.9020
# Pred Range: 0.0000 to 0.7912
# Target Range: 0.0000 to 0.8922
# Epoch 12/20 | train: 0.077 | val: 0.077 | blur: 994.485 | MAE: 12.538 | RMSE: 17.900 | RAPSD-dist: 0.788
# Input Range: 0.0000 to 0.9069
# Pred Range: 0.0000 to 0.7853
# Target Range: 0.0000 to 0.9069
# Epoch 13/20 | train: 0.077 | val: 0.077 | blur: 932.381 | MAE: 12.796 | RMSE: 18.203 | RAPSD-dist: 0.794
# Input Range: 0.0000 to 0.9216
# Pred Range: 0.0000 to 0.7832
# Target Range: 0.0000 to 0.9363
# Epoch 14/20 | train: 0.077 | val: 0.077 | blur: 935.850 | MAE: 12.727 | RMSE: 18.115 | RAPSD-dist: 0.793
# Input Range: 0.0000 to 0.8873
# Pred Range: 0.0000 to 0.7617
# Target Range: 0.0000 to 0.8971
# Epoch 15/20 | train: 0.077 | val: 0.077 | blur: 965.989 | MAE: 12.619 | RMSE: 18.017 | RAPSD-dist: 0.786
# Input Range: 0.0000 to 0.9216
# Pred Range: 0.0000 to 0.7950
# Target Range: 0.0000 to 0.9167
# Epoch 16/20 | train: 0.077 | val: 0.076 | blur: 1035.423 | MAE: 12.889 | RMSE: 18.250 | RAPSD-dist: 0.800
# Input Range: 0.0000 to 0.9020
# Pred Range: 0.0000 to 0.7883
# Target Range: 0.0000 to 0.9020
# Epoch 17/20 | train: 0.077 | val: 0.077 | blur: 1007.035 | MAE: 12.961 | RMSE: 18.374 | RAPSD-dist: 0.808
# Input Range: 0.0000 to 0.8873
# Pred Range: 0.0000 to 0.8050
# Target Range: 0.0000 to 0.9167
# Epoch 18/20 | train: 0.077 | val: 0.076 | blur: 1031.638 | MAE: 12.696 | RMSE: 18.064 | RAPSD-dist: 0.789
# Input Range: 0.0000 to 0.8775
# Pred Range: 0.0000 to 0.7509
# Target Range: 0.0000 to 0.8529
# Epoch 19/20 | train: 0.077 | val: 0.076 | blur: 988.376 | MAE: 13.355 | RMSE: 18.708 | RAPSD-dist: 0.817
# Input Range: 0.0000 to 0.8824
# Pred Range: 0.0000 to 0.7436
# Target Range: 0.0000 to 0.8873
# Epoch 20/20 | train: 0.077 | val: 0.076 | blur: 1041.191 | MAE: 13.048 | RMSE: 18.382 | RAPSD-dist: 0.803
# Evaluating model...
# Final loss on test set: 0.077 // final blur on test set: 1068.333 // MAE: 12.623 // RMSE: 17.998 // RAPSD-dist: 0.796
# Saved final model parameters to checkpoints/final_model.pt
# Done!

# %%
# %%time
print("hello")
