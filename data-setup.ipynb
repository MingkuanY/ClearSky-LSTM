# %% [markdown]
# # Download data

# %%
# !python download_nexrad.py \
#     --stations KAMX \
#     --start 2024-04-01 --end 2024-10-31 \
#     --workers 8 \
#     --out data/raw
# !python cache_nexrad.py --stations KAMX
