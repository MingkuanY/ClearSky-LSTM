# %%
import sys
print(sys.executable)
# Out:
# /home/hice1/mchoi345/.conda/envs/dl2/bin/python

# %%
# teacher forcing does not work for this
# !{sys.executable} clearsky_lstm.py \
  --loss-function l2 \
  --model-out checkpoints/base_network_cand_l2.pt \
  --model base_network_cand \
  --stations KAMX \
  --t-in 5 \
  --t-out 5 \
  --batch-size 16 \
  --epochs 20 \
  --lr 0.001 \
  --hidden-ch 64 64 \
  --num-layers 2 \
  --window-stride 5 \
  --precision amp \
  --train-start-date 2024-04-01 \
  --train-end-date 2024-10-31 \
  --test-start-date 2025-04-01 \
  --test-end-date 2025-10-31 \
  --seed 13
# Out:
# Starting model...
# Arguments parsed! sample_dir=samples/20260412/base_network_cand/l2/ilgafmyi results_dir=results/20260412/base_network_cand/l2/ilgafmyi
# Building dataset...
# Train/val/test split complete!
# Model built!
# Beginning training...
# Using loss function: l2
# Using precision: amp
# Note: higher blur score = sharper image!
# Train 1/20:   0%|                                       | 0/628 [00:00<?, ?it/s]Input Range: 0.0000 to 0.9020
# Pred Range: 0.5000 to 0.5127
# Target Range: 0.0000 to 0.8971
# Epoch 1/20 | train: 0.017 | val: 0.015 | blur: 12.711 | MAE: 9.314 | RMSE: 12.528 | RAPSD-dist: 2.884
# Train 2/20:   0%|                                       | 0/628 [00:00<?, ?it/s]Input Range: 0.0000 to 0.9069
# Pred Range: 0.0148 to 0.6650
# Target Range: 0.0000 to 0.9412
# Epoch 2/20 | train: 0.015 | val: 0.015 | blur: 18.004 | MAE: 9.134 | RMSE: 12.343 | RAPSD-dist: 2.327
# Train 3/20:   0%|                                       | 0/628 [00:00<?, ?it/s]Input Range: 0.0000 to 0.8824
# Pred Range: 0.0121 to 0.7109
# Target Range: 0.0000 to 0.8873
# Epoch 3/20 | train: 0.015 | val: 0.014 | blur: 67.885 | MAE: 9.035 | RMSE: 12.261 | RAPSD-dist: 1.798
# Train 4/20:   0%|                                       | 0/628 [00:00<?, ?it/s]Input Range: 0.0000 to 0.9216
# Pred Range: 0.0088 to 0.7505
# Target Range: 0.0000 to 0.9069
# Epoch 4/20 | train: 0.015 | val: 0.014 | blur: 76.562 | MAE: 8.993 | RMSE: 12.209 | RAPSD-dist: 1.762
# Train 5/20:   0%|                                       | 0/628 [00:00<?, ?it/s]Input Range: 0.0000 to 0.9314
# Pred Range: 0.0078 to 0.7520
# Target Range: 0.0000 to 0.9265
# Train 5/20:  22%|███▌            | 141/628 [03:17<11:20,  1.40s/it, loss=0.0145]

# %%
# !{sys.executable} clearsky_lstm.py \
  --loss-function l1 \
  --model-out checkpoints/base_network_cand_l1.pt \
  --model base_network_cand \
  --stations KAMX \
  --t-in 5 \
  --t-out 5 \
  --batch-size 16 \
  --epochs 20 \
  --lr 0.0001 \
  --hidden-ch 64 64 \
  --num-layers 2 \
  --window-stride 5 \
  --precision amp \
  --train-start-date 2024-04-01 \
  --train-end-date 2024-10-31 \
  --test-start-date 2025-04-01 \
  --test-end-date 2025-10-31 \
  --seed 13
